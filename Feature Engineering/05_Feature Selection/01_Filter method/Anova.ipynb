# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import seaborn as sns

# %%
x_train = pd.read_csv("../../human_train.csv").drop(["Activity","subject"],axis=1)
x_test = pd.read_csv("../../human_test.csv").drop(["Activity","subject"],axis=1)
y_train = pd.read_csv("../../human_train.csv",usecols=["Activity"])
y_test = pd.read_csv("../../human_test.csv",usecols=["Activity"])

# %%
x_train.shape , x_test.shape
# Out:
# ((7352, 561), (2947, 561))

# %%
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import SelectKBest


sel = SelectKBest(f_classif, k=100).fit(x_train, y_train)

# display selected feature names
x_train.columns[sel.get_support()]
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Index(['tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-mad()-X',
#        'tBodyAcc-mad()-Y', 'tBodyAcc-max()-X', 'tBodyAcc-min()-X',
#        'tBodyAcc-min()-Y', 'tBodyAcc-sma()', 'tBodyAcc-iqr()-X',
#        'tBodyAcc-iqr()-Y', 'tGravityAcc-mean()-X', 'tGravityAcc-max()-X',
#        'tGravityAcc-min()-X', 'tGravityAcc-energy()-X', 'tBodyAccJerk-std()-X',
#        'tBodyAccJerk-std()-Y', 'tBodyAccJerk-mad()-X', 'tBodyAccJerk-mad()-Y',
#        'tBodyAccJerk-max()-X', 'tBodyAccJerk-min()-X', 'tBodyAccJerk-sma()',
#        'tBodyAccJerk-iqr()-X', 'tBodyAccJerk-iqr()-Y',
#        'tBodyAccJerk-entropy()-X', 'tBodyAccJerk-entropy()-Y',
#        'tBodyAccJerk-entropy()-Z', 'tBodyGyro-sma()',
#        'tBodyGyroJerk-entropy()-X', 'tBodyGyroJerk-entropy()-Y',
#        'tBodyGyroJerk-entropy()-Z', 'tBodyAccMag-mean()', 'tBodyAccMag-std()',
#        'tBodyAccMag-mad()', 'tBodyAccMag-max()', 'tBodyAccMag-sma()',
#        'tBodyAccMag-entropy()', 'tGravityAccMag-mean()',
#        'tGravityAccMag-std()', 'tGravityAccMag-mad()', 'tGravityAccMag-max()',
#        'tGravityAccMag-sma()', 'tGravityAccMag-entropy()',
#        'tBodyAccJerkMag-mean()', 'tBodyAccJerkMag-std()',
#        'tBodyAccJerkMag-mad()', 'tBodyAccJerkMag-max()',
#        'tBodyAccJerkMag-sma()', 'tBodyAccJerkMag-iqr()',
#        'tBodyAccJerkMag-entropy()', 'tBodyGyroMag-mean()',
#        'tBodyGyroMag-sma()', 'tBodyGyroJerkMag-entropy()', 'fBodyAcc-mean()-X',
#        'fBodyAcc-mean()-Y', 'fBodyAcc-std()-X', 'fBodyAcc-std()-Y',
#        'fBodyAcc-mad()-X', 'fBodyAcc-mad()-Y', 'fBodyAcc-max()-X',
#        'fBodyAcc-sma()', 'fBodyAcc-iqr()-X', 'fBodyAcc-iqr()-Y',
#        'fBodyAcc-entropy()-X', 'fBodyAcc-entropy()-Y', 'fBodyAcc-entropy()-Z',
#        'fBodyAccJerk-mean()-X', 'fBodyAccJerk-mean()-Y',
#        'fBodyAccJerk-std()-X', 'fBodyAccJerk-std()-Y', 'fBodyAccJerk-mad()-X',
#        'fBodyAccJerk-mad()-Y', 'fBodyAccJerk-max()-X', 'fBodyAccJerk-sma()',
#        'fBodyAccJerk-iqr()-X', 'fBodyAccJerk-iqr()-Y',
#        'fBodyAccJerk-entropy()-X', 'fBodyAccJerk-entropy()-Y',
#        'fBodyAccJerk-entropy()-Z', 'fBodyGyro-mean()-Z', 'fBodyGyro-mad()-Z',
#        'fBodyGyro-sma()', 'fBodyGyro-entropy()-X', 'fBodyGyro-entropy()-Y',
#        'fBodyGyro-entropy()-Z', 'fBodyAccMag-mean()', 'fBodyAccMag-std()',
#        'fBodyAccMag-mad()', 'fBodyAccMag-sma()', 'fBodyAccMag-iqr()',
#        'fBodyAccMag-entropy()', 'fBodyBodyAccJerkMag-mean()',
#        'fBodyBodyAccJerkMag-std()', 'fBodyBodyAccJerkMag-mad()',
#        'fBodyBodyAccJerkMag-max()', 'fBodyBodyAccJerkMag-sma()',
#        'fBodyBodyAccJerkMag-iqr()', 'fBodyBodyAccJerkMag-entropy()',
#        'fBodyBodyGyroMag-entropy()', 'fBodyBodyGyroJerkMag-entropy()',
#        'angle(X,gravityMean)'],
#       dtype='object')

# %%
columns = x_train.columns[sel.get_support()]

# %%
x_train = sel.transform(x_train)
x_test = sel.transform(x_test)

x_train = pd.DataFrame(x_train, columns=columns)
x_test = pd.DataFrame(x_test, columns=columns)

# %%
x_train.shape,x_test.shape
# Out:
# ((7352, 100), (2947, 100))

# %%
x_train.head()
# Out:
#    tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.995279         -0.983111         -0.995112         -0.983185
# 1         -0.998245         -0.975300         -0.998807         -0.974914
# 2         -0.995380         -0.967187         -0.996520         -0.963668
# 3         -0.996091         -0.983403         -0.997099         -0.982750
# 4         -0.998139         -0.980817         -0.998321         -0.979672
#
#    tBodyAcc-max()-X  tBodyAcc-min()-X  tBodyAcc-min()-Y  tBodyAcc-sma()  \
# 0         -0.934724          0.852947          0.685845       -0.965523
# 1         -0.943068          0.849308          0.685845       -0.981930
# 2         -0.938692          0.843609          0.682401       -0.983478
# 3         -0.938692          0.843609          0.682401       -0.986093
# 4         -0.942469          0.849095          0.683250       -0.992653
#
#    tBodyAcc-iqr()-X  tBodyAcc-iqr()-Y  ...  fBodyBodyAccJerkMag-mean()  \
# 0         -0.994231         -0.987614  ...                   -0.993726
# 1         -0.999150         -0.977866  ...                   -0.990335
# 2         -0.997130         -0.964810  ...                   -0.989280
# 3         -0.997180         -0.983799  ...                   -0.992769
# 4         -0.998004         -0.981232  ...                   -0.995523
#
#    fBodyBodyAccJerkMag-std()  fBodyBodyAccJerkMag-mad()  \
# 0                  -0.993755                  -0.991976
# 1                  -0.991960                  -0.989732
# 2                  -0.990867                  -0.987274
# 3                  -0.991700                  -0.989055
# 4                  -0.994389                  -0.993305
#
#    fBodyBodyAccJerkMag-max()  fBodyBodyAccJerkMag-sma()  \
# 0                  -0.993365                  -0.993726
# 1                  -0.994489                  -0.990335
# 2                  -0.993179                  -0.989280
# 3                  -0.994455                  -0.992769
# 4                  -0.995485                  -0.995523
#
#    fBodyBodyAccJerkMag-iqr()  fBodyBodyAccJerkMag-entropy()  \
# 0                  -0.991364                           -1.0
# 1                  -0.991134                           -1.0
# 2                  -0.986658                           -1.0
# 3                  -0.988055                           -1.0
# 4                  -0.994169                           -1.0
#
#    fBodyBodyGyroMag-entropy()  fBodyBodyGyroJerkMag-entropy()  \
# 0                   -0.701291                       -0.871306
# 1                   -0.720683                       -1.000000
# 2                   -0.736521                       -1.000000
# 3                   -0.720891                       -0.955696
# 4                   -0.763372                       -1.000000
#
#    angle(X,gravityMean)
# 0             -0.841247
# 1             -0.844788
# 2             -0.848933
# 3             -0.848649
# 4             -0.847865
#
# [5 rows x 100 columns]
